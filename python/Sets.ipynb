# %% [markdown]
# sets are built in data sturcture in pyhton that represent an unordered collection of unique elements.
# they are particularly useful fo operational involving membership tsting removing duplicates and mathematical set operations

# %%
# creating a set
numbers = {1,2,3,4,5}
print (numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(numbers)
# Out:
# set

# %%
fruits = {"Apple","mango","Banana","Apple"} # it show one apple because it does not contain duplicate values
print(fruits)
# Out:
# {'mango', 'Banana', 'Apple'}

# %%
# acess the elements 
for elements in fruits:
    print(elements)
# Out:
# mango
# Banana
# Apple

# %%
fruits.add("Grapes")
print(fruits)
# Out:
# {'mango', 'Banana', 'Apple', 'Grapes'}

# %%
fruits.remove("Apple")
print(fruits)
# Out:
# {'mango', 'Banana', 'Grapes'}
