# %% [markdown]
# Tuples are immutable and fundamental data structure in pyhton used to store collection of items
# Tuples can contain elements of different data types.
# tuples are ordered meaning the items have a defined sequences

# %%
# creating a tuple
fruits = ("apple", "banana","mango")
numbers=(1,2,3,4)
mix=(1,"John",2.5,True)
print(fruits)
print(numbers)
# Out:
# ('apple', 'banana', 'mango')
# (1, 2, 3, 4)

# %%
type(numbers)
# Out:
# tuple

# %%
# Acess the elements
fruits[1]
# Out:
# 'banana'

# %%
fruits[1]="Grapes" # give error because tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fruits[1]="Grapes"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# used for static data like sales the data that is not change so we use tuple
