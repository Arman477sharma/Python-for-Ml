# %%
# basic syntax
print("Hello world")
# Out:
# Hello world

# %%
# indentation
def greet(name):
    print(f"Hello",{name})

greet("Arman")
# Out:
# Hello {'Arman'}

# %%
# variables
first_name="Arman"
last_name="Sharma" # last_name is varible and its value is sahrma

print(first_name + last_name)
# Out:
# ArmanSharma

# %% [markdown]
# data types:
# integer
# float
# string
# boolean
#  type conversion allws you to cahnge the type of value form one data type to another

# %%
name="Arman Sharma" # string data type
age =20 # int
height =5.8 #float
isMarried =True #boolean

print(name)
print(age)
print(height)
print(isMarried)
print(type(name)) # define varible type belong to which data type
# Out:
# Arman Sharma
# 20
# 5.8
# True
# <class 'str'>
